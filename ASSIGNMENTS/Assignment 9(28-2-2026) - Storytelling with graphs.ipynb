# %%
import matplotlib.pyplot as plt
import pandas as pd

# Creating dataset
data = {
    "Month": ["Jan", "Feb", "Mar", "Apr", "May", "Jun"],
    "Sales": [200, 250, 300, 280, 350, 400]
}

df = pd.DataFrame(data)

# 1️⃣ Bar Chart
plt.figure()
plt.bar(df["Month"], df["Sales"])
plt.title("Monthly Sales Bar Chart")
plt.xlabel("Month")
plt.ylabel("Sales")
plt.savefig("bar_chart.png")
plt.show()

# 2️⃣ Pie Chart
plt.figure()
plt.pie(df["Sales"], labels=df["Month"], autopct='%1.1f%%')
plt.title("Sales Distribution Pie Chart")
plt.savefig("pie_chart.png")
plt.show()

# 3️⃣ Histogram
plt.figure()
plt.hist(df["Sales"], bins=5)
plt.title("Sales Histogram")
plt.xlabel("Sales")
plt.ylabel("Frequency")
plt.savefig("histogram.png")
plt.show()

# %% [raw]
# ✔ Bar Chart
#
# The bar chart represents monthly sales comparison.
# It clearly shows how sales increased from January to March, slightly dropped in April, and then significantly increased in May and June.
#
# ✔ Pie Chart
#
# The pie chart shows the percentage contribution of each month to total sales.
# June contributes the highest share, while January contributes the lowest.
#
# ✔ Histogram
#
# The histogram represents the frequency distribution of sales values.
# It shows that most sales values lie in the higher range (280–400), indicating an overall upward sales trend.
